# %% [markdown]
# Usar las imágenes de arroz (rice-1.jpg y rice.png) Usar la función edge de Octave.
# aplicar los siguientes filtros
# • Sobel
# • Prewitt • Canny
# Mostrar las cuatro imagenes en un mismo cuadro de ploteo
# En un párrafo de al menos cinco oraciones escribe una conclusión al respecto

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('Imagenes_Pruebas/prueba1.jpg',0)
edges = cv2.Canny(img,100,200)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# Información extraida de:
#     https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_canny/py_canny.html
