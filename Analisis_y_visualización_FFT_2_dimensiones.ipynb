# %% [markdown]
# A continuación se muestra el código que pide el ejercicio
#
# Barra horizontal negra
#
# I=ones(100,100);
#
# I(45:55,25:75)=0;
#
# imshow(I)
#
# F=fft2(I);
#
# F1=log(1+abs(F));
#
# figure,imshow(F1);
#
# freqz2(F1)
#
# %Desplazando
#
# F1=fftshift(F);
#
# F2=log(1+abs(F1));
#
# figure,imshow(F2);
#
# freqz2(F2)
#
# Concluya al respecto al visualizar ambos resultados.
#
#
# Datos extra:
#
#
# La transformada de Fourier se utiliza para analizar las características de frecuencia de varios filtros. Para las imágenes, la transformada discreta de Fourier 2D (DFT, por sus siglas en inglés) se utiliza para encontrar el dominio de frecuencia. Para el cálculo de la DFT se utiliza un algoritmo rápido llamado Transformada Rápida de Fourier (o Fast Fourier Transform en inglés, abreviado como FFT). Los detalles al respecto se pueden encontrar en cualquier libro de texto de procesamiento de imágenes o procesamiento de señales.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
#configuracion necesaria de pyplot para ver las imagenes en escala de grises
plt.rcParams['image.cmap'] = 'gray'

# comando de Jupyter para que las imagenes se muestren automaticamente 
# %matplotlib inline
imagen=np.ones((100, 100))
plt.imshow(imagen,vmin=0,vmax=1)

# %%
imagen[5:10,45:55]=0;

plt.imshow(imagen,vmin=0,vmax=1)

# %%
import math
import sys
import math


f = np.fft.fft2(imagen)
fshift = np.fft.fftshift(f)
magnitudFFT = 20*np.log(1+np.abs(fshift))

plt.rcParams['image.cmap'] = 'gray'
plt.subplot(121),plt.imshow(imagen, cmap = 'gray')
plt.title('Imagen de entrada'), plt.xticks([]), plt.yticks([])


plt.subplot(122),plt.imshow(magnitudFFT, cmap = 'gray')
plt.title('DFT'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
f = np.fft.fft2(imagen)

sin= 20*np.log(1+np.abs(f))

plt.subplot(121),plt.imshow(imagen, cmap = 'gray')
plt.title('Imagen de entrada'), plt.xticks([]), plt.yticks([])


plt.subplot(122),plt.imshow(sin, cmap = 'gray')
plt.title('FFT'), plt.xticks([]), plt.yticks([])
plt.show()


plt.subplot(121),plt.imshow(imagen, cmap = 'gray')
plt.title('Imagen de entrada'), plt.xticks([]), plt.yticks([])


plt.subplot(122),plt.imshow(magnitudFFT, cmap = 'gray')
plt.title('DFT'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Transformada de Fourier en OpenCV

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = imagen
dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = 20*np.fft.fftshift(1+dft)
magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Imagen de entrada'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('DFT'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Datos adicionales sobre esta tarea:
#     https://www.aprenderpython.net/transformada-de-fourier/
#
#         https://www.unioviedo.es/compnum/laboratorios_py/Fourier/Fourier2D.html
