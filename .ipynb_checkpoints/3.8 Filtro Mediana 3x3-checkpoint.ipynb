# %% [markdown]
# # Filtro Mediana 3x3
#
# # Ejercicio 3.8
#
#
# * Programar tu propia función de filtro de mediana, el cual remueve ruido tipo Sal y Pimienta.
# * Probar con la imagen resultante de usar tu función saltanpeppa. Comparar y comentar
# * Probar con la imagen resultante de usar imnoise.Comparar y comentar

# %%
#Ejecutar para ver imagen original
from skimage import io

original = io.imread('cerebro.JPG')
io.imshow(original)
# Out:
# C:\Users\SARA\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\SARA\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
#Ejecutar para ver imagen con ruido
from skimage import io

original = io.imread('cerebro_sp.JPG')
io.imshow(original)
# Out:
# C:\Users\SARA\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\SARA\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
import numpy as np
import cv2
from skimage import io

noisy = io.imread('cerebro_sp.JPG',0)
median_blur= cv2.medianBlur(noisy, 3)
io.imshow(median_blur)
# Out:
# C:\Users\SARA\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\SARA\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)
