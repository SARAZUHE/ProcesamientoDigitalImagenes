# %% [markdown]
# # Normalizando una imagen y ajuste de contraste
#
# Suponga que trabjamos con la siguiente figura del tumor llamado Condrosarcoma que
# es un tipo de tumor maligno o cáncer que afecta al cartilago, es la segunda neoplasia ósea más
# frecuente dentro del grupo de los tumores óseos primarios malignos y se desea observar con mejor
# contrasate el mismo. Se desea aplicar una transformación puntual a dicha imagen de manera que se ajuste los tonos de gris al rango de [0 255], la transformación más sencilla consiste como
# se muestra en la siguiente figura 2.3 El valor de a se determina por la condición que T(63) = 255
# es decir a * 63 = 255 ≅ 4,05. Como la pendiente es mayor a uno, la imagen aumenta el contraste
# en el intervalo [0, 63].
#
#
# # Contraste de una imágen, transformación lineal
#
# # Ejercicio 3
#
# A continuación se muestra una forma de implementar similar a la anterior:

# %%
#Ejecutar para ver imagen original NO ELIMINAR 
from skimage import io

original = io.imread('cerebro_gr.JPG')
io.imshow(original)
# Out:
# C:\Users\SARA\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\SARA\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
#RESCATAR SOLO ESTA PANTALLA AL FINAL :D las otras son para no perderme con los ejemplos y poder rescatarlos rapido 
import matplotlib.pyplot as plt
from skimage import io
from skimage.color import rgb2gray
I= io.imread('cerebro.JPG')
I1 = cv2.normalize(I.astype('float'), None, 0.0, 1.0, cv2.NORM_MINMAX)
print("Dimensiones primera imágen")
print(I1.shape)
IG= rgb2gray(I1)
io.imsave('cerebro_gr.JPG', IG)
print("Dimensiones imágen escala de grises")
print(IG.shape)
I2 = IG
for n in range(0,325):
    for m in range(0,324):
        I2[m][n] = IG[m][n]*255/63
        if (I2[m][n]>1):
            I2[m][n] = 1
io.imshow(I2)
# Out:
# Dimensiones primera imágen
# (326, 325, 3)
# Dimensiones imágen escala de grises
# (326, 325)
# C:\Users\SARA\Anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\SARA\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\SARA\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)
