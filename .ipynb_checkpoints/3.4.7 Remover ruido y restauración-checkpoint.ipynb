# %% [markdown]
# # Remover ruido y restauración
#
# # Ejercicio 3.4.7
#
#
# La imagen con la que trabajaremos es circuito-ruido.jpeg
#
# Convertir a escala de grises.
#
# Al filtrar la imagen para remover ruido indique si se difuminan o suavizan detalles.
#
# Proponer un filtro que remueva el ruido en base a lo observado. Utilice la función fspecial con ventana de 5x5
#
# Filtrar con filter2 para remover el ruido y ponderar el resultado a 255
#
# Identificar que tipo de filtro funciona mejor para la imagen del circuito.
#
# Restarurar la imagen filtrada con la máscara de desenfoque o unsharp,usando fspecial
#
# Obtener el valor absoluto de filtrar usando filter2 para mejorar la imagen
#
# Mostrar las imágenes resultantes y la original

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


image = cv2.imread('original.JPG')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gaussian_3 = cv2.GaussianBlur(gray_image, (5,5), 10.0)
unsharp_image = cv2.addWeighted(gray_image, 1.5, gaussian_3, -0.5, 0, image)


plt.subplot(121),plt.imshow(image,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(gaussian_3,cmap = 'gray')
plt.title('Gaussian Image'), plt.xticks([]), plt.yticks([])
plt.show()
plt.subplot(121),plt.imshow(unsharp_image,cmap = 'gray')
plt.title('Unsharp Image'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5,1,'Unsharp Image'),
#  ([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))
