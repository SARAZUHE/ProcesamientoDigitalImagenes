# %% [markdown]
# Programar tu propia función de añadir ruido Sal y Pimienta saltanpeppa.
# La función debe tener su propia ayuda de la misma forma como se realizó el caso
# del Ruido Impulsivo.
# La función recibe como parámetros la imagen y el porcentaje de ruido que deseas añadir,
# La función retorna la imagen con ruido sal y pimienta
# Añadir ruido sal y pimienta con la función imnoise y comparar los resultados para diferentes cantidades de ruido.
# Añadir sal y pimienta manualmente
# //donde tendremos la imagen con ruido
# Ar=A;
#
#
# for i=1:f*c
#
#       if rand<0.05
#
#          Ar(i)=0;
#
#      end
#
#      if rand>0.95
#
#          Ar(i)=255;
#
#       end
#
# end

# %%
import random
from PIL import Image

def ruido(imagen, porcentaje):

    tamaño=imagen.size[0]*imagen.size[1]
    auxiliar=(tamaño*porcentaje)//800
 
    if imagen.mode=='RGB':
        dato_minimo=(0, 0, 0)
        dato_maximo=(255, 255, 255)
 
    elif imagen.mode=='L':
        dato_minimo=0
        dato_maximo=255
 
    #pixeles blancos
    for x in range(auxiliar):
 
        coordenada_x=random.randrange(2, imagen.width-2)
        coordenada_y=random.randrange(2, imagen.height-2)
 
        imagen.putpixel((coordenada_x, coordenada_y), dato_maximo)
        imagen.putpixel((coordenada_x+1, coordenada_y), dato_maximo)
        imagen.putpixel((coordenada_x, coordenada_y+1), dato_maximo)
        imagen.putpixel((coordenada_x+1, coordenada_y+1), dato_maximo)
 
    #pixeles negros
    for x in range(auxiliar):
 
        coordenada_x=random.randrange(2, imagen.width-2)
        coordenada_y=random.randrange(2, imagen.height-2)
 
        imagen.putpixel((coordenada_x, coordenada_y), dato_minimo)
        imagen.putpixel((coordenada_x+1, coordenada_y), dato_minimo)
        imagen.putpixel((coordenada_x, coordenada_y+1), dato_minimo)
        imagen.putpixel((coordenada_x+1, coordenada_y+1), dato_minimo)
 
    return None

# %%
# %matplotlib inline

import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image, ImageFilter
    
foto=Image.open('Imagenes_Pruebas/prueba1.jpg')#llamado a la funcion pasando como parametro la imagen y el
#porcentaje de ruido deseado
plt.subplot(121),plt.imshow(foto),plt.title('Original')
plt.xticks([]), plt.yticks([])

ruido(foto, 20)
plt.subplot(122),plt.imshow(foto),plt.title('Sal y pimienta')
plt.xticks([]), plt.yticks([])


foto.save('Imagenes_Pruebas/sal_pimienta.jpg')
foto.close()
