# %% [markdown]
# Usar imfilter con las ventanas obtenidas con fspecial, por ejemplo si usamos el filtro laplaciano debe ser así:
#
#      I = imread(’cameraman.tif’);
#
#      imshow(I)
#
#         H = fspecial(’laplacian’);
#
#         Laplacian = imfilter(I,H,’replicate’);
#
#         figure, imshow(Laplacian)
#
# Seleccionar imágenes donde se pueda apreciar el resultado de aplicar los filtros.
#
# Esta función no existe en Python por lo cual utilice bibliotecas de cv2 para ir aplicando los filtros que solicita este problema.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('Imagenes_Pruebas/prueba1.jpg',0)

laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# Información extraida de:
#     https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_gradients/py_gradients.html
